# %% [markdown]
# ##Summon any data

# %% [markdown]
# I want to make a single query and have it return data across the datasets

# %%
from datetime import datetime,timedelta, time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_helper_functions import *
from IPython.display import display
pd.options.display.max_columns = 999
# %matplotlib inline

desired_channel = 'BAND_01'
desired_date = datetime(2014, 4, 1)
desired_timedelta = timedelta(hours = 15)
desired_datetime = desired_date + desired_timedelta
satellite_filefolder = '../../data/satellite/colorado/summer6months/data/'
sensor_filefolder = '../../data/sensor_data/colorado6months/'
pvoutput_filefolder = '../../data/pvoutput/pvoutput6months/'

#satellite data
satellite_filename = find_filename(desired_datetime, desired_channel, satellite_filefolder)
lons, lats, data = return_satellite_data(satellite_filename, satellite_filefolder)


plt.figure(figsize=(8, 8))
imgplot = plt.imshow(data)
imgplot.set_interpolation('none')
plt.savefig('foo.png')
plt.show()

#sensor data
sensor_filename = find_file_from_date(desired_date, sensor_filefolder)
df_sensor = return_sensor_data(sensor_filename, sensor_filefolder)
df_sensor[df_sensor.index == desired_datetime]
display(df_sensor[df_sensor.index == desired_datetime])

#pvoutput data
pvoutput_filename = find_file_from_date(desired_date, pvoutput_filefolder)
df_pvoutput = return_pvoutput_data(pvoutput_filename, pvoutput_filefolder)
display(df_pvoutput[df_pvoutput.index == desired_datetime])

#saving df to image

# a = Image(data=df_sensor)
# type(a)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0ab7b91631d9> in <module>()
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 from data_helper_functions import *
#       6 from IPython.display import display
#       7 pd.options.display.max_columns = 999
#
# ImportError: No module named data_helper_functions

# %% [markdown]
# ##Build up sensor to pvoutput model

# %%
from datetime import datetime,timedelta, time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_helper_functions import *
from IPython.display import display
pd.options.display.max_columns = 999
# %matplotlib inline

#iterate over datetimes:
mytime = datetime(2014, 4, 1, 13)
times = make_time(mytime)

# Now that we can call data up over any datetime and we have a list of interested datetimes,
# we can finally construct an X matrix and y vector for regression.

sensor_filefolder = 'data/sensor_data/colorado6months/'
pvoutput_filefolder = 'data/pvoutput/pvoutput6months/'

X = [] #Sensor values
y = [] #PVOutput

for desired_datetime in times:
    
    try: #something wrong with y on last day
        desired_date = (desired_datetime - timedelta(hours=6)).date() #make sure correct date
        desired_date = datetime.combine(desired_date, time.min) #get into datetime format

        sensor_filename = find_file_from_date(desired_date, sensor_filefolder)
        df_sensor = return_sensor_data(sensor_filename, sensor_filefolder).ix[:,-15:-1]
        df_sensor[df_sensor.index == desired_datetime]

        pvoutput_filename = find_file_from_date(desired_date, pvoutput_filefolder)
        df_pvoutput = return_pvoutput_data(pvoutput_filename, pvoutput_filefolder)
        
        y.append(df_pvoutput[df_pvoutput.index == desired_datetime].values[0][0])
        X.append(df_sensor[df_sensor.index == desired_datetime].values[0])
    except:
        pass

# %%
X = np.array(X)
y = np.array(y)

# %%
print X.shape
print y.shape
# Out:
# (2729, 14)
# (2729,)

# %% [markdown]
# ...finally ready to model!

# %% [markdown]
# ###Random Forest

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=99)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(oob_score = True)

# %%
rfr.fit(X_train,y_train)
# Out:
# /Users/scott/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:659: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False)

# %%
y_pred = rfr.predict(X_test)

# %%
rfr.score(X_test,y_test)
# Out:
# 0.7490756392067901

# %%
df_sensor.columns.values.shape
# Out:
# (14,)

# %%
sorted_mask = np.argsort(rfr.feature_importances_)

for i in zip(df_sensor.columns.values,rfr.feature_importances_[sorted_mask])[::-1]:
    print i
# Out:
# ('1020nm Obsolete AOD', 0.29705980474717808)
# ('940nm Obsolete AOD', 0.17174617509650866)
# ('870nm Obsolete AOD', 0.17083940295469266)
# ('675nm Obsolete AOD', 0.071429494096470258)
# ('500nm Obsolete AOD', 0.045184771111814695)
# ('400nm Obsolete AOD', 0.036439937457282537)
# ('315nm Obsolete AOD', 0.03505373030081841)
# ('1020nm POM-01 Photometer [uA]', 0.031564635340118663)
# ('940nm POM-01 Photometer [uA]', 0.031207228143303643)
# ('870nm POM-01 Photometer [uA]', 0.025846240358196205)
# ('675nm POM-01 Photometer [uA]', 0.024115547890639334)
# ('500nm POM-01 Photometer [uA]', 0.023503414572774273)
# ('400nm POM-01 Photometer [uA]', 0.020845598241361792)
# ('315nm POM-01 Photometer [nA]', 0.015164019688840746)

# %% [markdown]
# ###Linear model

# %%
#now do a linear model and compare:
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# -48.833843056591832

# %%
sorted_mask = np.argsort(lr.coef_)

for i in zip(df_sensor.columns.values,lr.coef_[sorted_mask])[::-1]:
    print i
# Out:
# ('1020nm Obsolete AOD', 25720.514248532258)
# ('940nm Obsolete AOD', 5787.6495593808249)
# ('870nm Obsolete AOD', 924.66656776148329)
# ('675nm Obsolete AOD', 266.2149419573488)
# ('500nm Obsolete AOD', 254.70915555929054)
# ('400nm Obsolete AOD', 0.18497028763408108)
# ('315nm Obsolete AOD', -12.098032718226079)
# ('1020nm POM-01 Photometer [uA]', -78.41950447932544)
# ('940nm POM-01 Photometer [uA]', -170.39792476852338)
# ('870nm POM-01 Photometer [uA]', -260.19451251012526)
# ('675nm POM-01 Photometer [uA]', -2952.8050029904844)
# ('500nm POM-01 Photometer [uA]', -3374.2232859668857)
# ('400nm POM-01 Photometer [uA]', -6081.5228897332427)
# ('315nm POM-01 Photometer [nA]', -20024.56399336789)

# %%
df_sensor.ix[:,-15:-1].head() #selects photometer and AOD, 
# useful in next iteration of using sensor data to fit
# Out:
#                      315nm POM-01 Photometer [nA]  \
# datetime
# 2014-09-29 07:00:00                             0
# 2014-09-29 08:00:00                             0
# 2014-09-29 09:00:00                             0
# 2014-09-29 10:00:00                             0
# 2014-09-29 11:00:00                             0
#
#                      400nm POM-01 Photometer [uA]  \
# datetime
# 2014-09-29 07:00:00                             0
# 2014-09-29 08:00:00                             0
# 2014-09-29 09:00:00                             0
# 2014-09-29 10:00:00                             0
# 2014-09-29 11:00:00                             0
#
#                      500nm POM-01 Photometer [uA]  \
# datetime
# 2014-09-29 07:00:00                             0
# 2014-09-29 08:00:00                             0
# 2014-09-29 09:00:00                             0
# 2014-09-29 10:00:00                             0
# 2014-09-29 11:00:00                             0
#
#                      675nm POM-01 Photometer [uA]  \
# datetime
# 2014-09-29 07:00:00                             0
# 2014-09-29 08:00:00                             0
# 2014-09-29 09:00:00                             0
# 2014-09-29 10:00:00                             0
# 2014-09-29 11:00:00                             0
#
#                      870nm POM-01 Photometer [uA]  \
# datetime
# 2014-09-29 07:00:00                             0
# 2014-09-29 08:00:00                             0
# 2014-09-29 09:00:00                             0
# 2014-09-29 10:00:00                             0
# 2014-09-29 11:00:00                             0
#
#                      940nm POM-01 Photometer [uA]  \
# datetime
# 2014-09-29 07:00:00                             0
# 2014-09-29 08:00:00                             0
# 2014-09-29 09:00:00                             0
# 2014-09-29 10:00:00                             0
# 2014-09-29 11:00:00                             0
#
#                      1020nm POM-01 Photometer [uA]  315nm Obsolete AOD  \
# datetime
# 2014-09-29 07:00:00                              0                   0
# 2014-09-29 08:00:00                              0                   0
# 2014-09-29 09:00:00                              0                   0
# 2014-09-29 10:00:00                              0                   0
# 2014-09-29 11:00:00                              0                   0
#
#                      400nm Obsolete AOD  500nm Obsolete AOD  \
# datetime
# 2014-09-29 07:00:00                   0                   0
# 2014-09-29 08:00:00                   0                   0
# 2014-09-29 09:00:00                   0                   0
# 2014-09-29 10:00:00                   0                   0
# 2014-09-29 11:00:00                   0                   0
#
#                      675nm Obsolete AOD  870nm Obsolete AOD  \
# datetime
# 2014-09-29 07:00:00                   0                   0
# 2014-09-29 08:00:00                   0                   0
# 2014-09-29 09:00:00                   0                   0
# 2014-09-29 10:00:00                   0                   0
# 2014-09-29 11:00:00                   0                   0
#
#                      940nm Obsolete AOD
# datetime
# 2014-09-29 07:00:00                   0
# 2014-09-29 08:00:00                   0
# 2014-09-29 09:00:00                   0
# 2014-09-29 10:00:00                   0
# 2014-09-29 11:00:00                   0

# %% [markdown]
# When only keeping the photometer data, random forest and linear model do pretty similar.  When I added all of the sensor instruments to the fit, rfr scored 0.87 and lr scored negative!
#
# Also, I threw away the mysterious "Research 2" sensor, that was probably just a solar panel!  I asked NREL what it is, so we'll see.  If it turns out to be a solar panel, then I can do some feature engineering with the sensor data by simulating a solar panel!

# %% [markdown]
# ###Neural Net Exploration

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
from lasagne import layers
from lasagne.nonlinearities import  softmax, rectify, sigmoid, linear, very_leaky_rectify, tanh
from lasagne.updates import nesterov_momentum, adagrad, momentum
from nolearn.lasagne import NeuralNet
import theano
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
y = y.astype('float32')
x = X.astype('float32')
scaler = StandardScaler()
scaled_x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(scaled_x, y, test_size = 0.2, random_state = 12)

# %%
nn_regression = NeuralNet(layers=[('input', layers.InputLayer),
#                                   ('hidden1', layers.DenseLayer),
#                                    ('hidden2', layers.DenseLayer),
                                  ('output', layers.DenseLayer)
                                ],

               # Input Layer
               input_shape=(None, x.shape[1]),

               # hidden Layer
#                hidden1_num_units=512,
#                hidden1_nonlinearity=softmax,
                          
             # hidden Layer
#                hidden2_num_units=128,
#                hidden2_nonlinearity=linear,

              # Output Layer
              output_num_units=1,
              output_nonlinearity=very_leaky_rectify,

              # Optimization
              update=nesterov_momentum,
              update_learning_rate=0.03,#0.02
              update_momentum=0.8,#0.8
              max_epochs=600, #was 100

              # Others
              #eval_size=0.2,
              regression=True,
              verbose=0,
         )

# %%
nn_regression.fit(x_train, y_train)
y_pred = nn_regression.predict(x_test)
nn_regression.score(x_test, y_test)
# Out:
# 14222684.509928443

# %%
val = 11
print y_pred[val][0]
print y_test[val]
# Out:
# 4136.2008404
# 2604.83

# %%
plt.plot(y_pred,'ro')

# %%
plt.plot(y_test,'go')

# %% [markdown]
# ##Extra Trees!

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor(oob_score=True, bootstrap=True,
                          n_jobs=-1, n_estimators=1000) #nj_obs uses all cores!
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

# %%
etr.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=True, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=1000, n_jobs=-1, oob_score=True, random_state=None,
#           verbose=0, warm_start=False)

# %%
print etr.score(X_test,y_test)
print etr.oob_score_
# Out:
# 0.790968287117
# 0.764343725942

# %%
y_pred = etr.predict(X_test)

from random import randint
val = randint(0,y_test.shape[0])
print y_pred[val]
print y_test[val]
# Out:
# 3977.51362318
# 4341.58

# %%
print X.shape
print y.shape
# Out:
# (2729, 14)
# (2729,)

# %% [markdown]
# Save this thing and try it out on the simulated sensors!

# %%
from sklearn.externals import joblib
joblib.dump(etr, 'data/sensor-to-power-model/sensor-to-power-model.pkl')
# Out:
# ['data/sensor-to-power-model/sensor-to-power-model.pkl',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_01.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_02.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_03.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_04.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_05.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_06.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_07.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_08.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_09.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_10.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_11.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_12.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_13.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_14.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_15.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_16.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_17.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_18.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_19.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_20.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_21.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_22.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_23.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_24.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_25.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_26.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_27.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_28.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_29.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_30.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_31.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_32.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_33.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_34.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_35.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_36.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_37.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_38.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_39.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_40.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_41.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_42.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_43.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_44.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_45.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_46.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_47.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_48.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_49.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_50.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_51.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_52.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_53.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_54.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_55.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_56.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_57.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_58.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_59.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_60.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_61.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_62.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_63.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_64.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_65.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_66.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_67.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_68.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_69.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_70.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_71.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_72.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_73.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_74.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_75.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_76.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_77.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_78.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_79.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_80.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_81.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_82.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_83.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_84.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_85.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_86.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_87.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_88.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_89.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_90.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_91.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_92.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_93.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_94.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_95.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_96.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_97.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_98.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_99.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_100.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_101.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_102.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_103.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_104.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_105.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_106.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_107.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_108.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_109.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_110.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_111.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_112.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_113.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_114.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_115.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_116.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_117.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_118.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_119.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_120.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_121.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_122.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_123.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_124.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_125.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_126.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_127.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_128.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_129.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_130.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_131.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_132.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_133.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_134.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_135.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_136.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_137.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_138.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_139.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_140.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_141.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_142.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_143.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_144.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_145.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_146.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_147.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_148.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_149.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_150.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_151.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_152.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_153.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_154.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_155.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_156.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_157.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_158.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_159.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_160.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_161.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_162.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_163.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_164.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_165.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_166.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_167.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_168.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_169.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_170.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_171.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_172.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_173.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_174.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_175.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_176.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_177.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_178.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_179.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_180.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_181.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_182.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_183.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_184.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_185.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_186.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_187.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_188.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_189.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_190.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_191.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_192.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_193.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_194.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_195.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_196.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_197.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_198.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_199.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_200.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_201.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_202.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_203.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_204.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_205.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_206.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_207.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_208.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_209.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_210.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_211.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_212.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_213.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl_214.npy',
#  'data/sensor-to-power-model/sensor-to-power-model.pkl