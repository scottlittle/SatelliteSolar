# %%
import pandas as pd

# %%
pd.read_csv('data/sensor_data/20140401_colorado_half_year.txt')
# Out:
#      DATE (MM/DD/YYYY)  HOUR-MST  Avg Global PSP (vent/cor) [W/m^2]  \
# 0             4/1/2014         1                             0.6957
# 1             4/1/2014         2                             0.9482
# 2             4/1/2014         3                             2.0993
# 3             4/1/2014         4                             1.8209
# 4             4/1/2014         5                             1.3090
# 5             4/1/2014         6                             4.8184
# 6             4/1/2014         7                           107.4835
# 7             4/1/2014         8                           329.1842
# 8             4/1/2014         9                           533.6923
# 9             4/1/2014        10                           641.9032
# 10            4/1/2014        11                           584.8415
# 11            4/1/2014        12                           384.2981
# 12            4/1/2014        13                           472.3512
# ...
