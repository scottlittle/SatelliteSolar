# %% [markdown]
# I want to make a single query and have it return data across the datasets

# %%
from datetime import datetime,timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_helper_functions import *
from IPython.display import display
pd.options.display.max_columns = 999
# %matplotlib inline

desired_channel = 'BAND_01'
desired_date = datetime(2014, 4, 8)
desired_timedelta = timedelta(hours = 18)
desired_datetime = desired_date + desired_timedelta
satellite_filefolder = 'data/satellite/colorado/summer6months/data/'
sensor_filefolder = 'data/sensor_data/colorado6months/'
pvoutput_filefolder = 'data/pvoutput/pvoutput6months/'

#satellite data
satellite_filename = find_filename(desired_datetime, desired_channel, satellite_filefolder)
lons, lats, data = return_satellite_data(satellite_filename, satellite_filefolder)

plt.figure(figsize=(8, 8))
imgplot = plt.imshow(data)
imgplot.set_interpolation('none')
plt.show()

#sensor data
sensor_filename = find_file_from_date(desired_date, sensor_filefolder)
df_sensor = return_sensor_data(sensor_filename, sensor_filefolder)
df_sensor[df_sensor.index == desired_datetime]
display(df_sensor[df_sensor.index == desired_datetime])

#pvoutput data
pvoutput_filename = find_file_from_date(desired_date, pvoutput_filefolder)
df_pvoutput = return_pvoutput_data(pvoutput_filename, pvoutput_filefolder)
display(df_pvoutput[df_pvoutput.index == desired_datetime])
# Out:
#                      nothing  Year  DOY  CR3000 CF Change [counts]  \
# datetime
# 2014-04-08 18:00:00        0  2014   98                          0
#
#                      CR3000 Zen Angle [degrees]  Global LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                   33.403757             945.304717
#
#                      Global CM22 (vent/cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                      939.800417
#
#                      Global RG780 PSP (vent/cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                             393.6841
#
#                      Global TSP-1 [W/m^2]  Global CM6b (cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00               960.874                    938.801
#
#                      Global SP Lite [W/m^2]  Global SP-110 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00               922.59395             897.575617
#
#                      Global TSP-700 Vent [W/m^2]  Research 1  Research 2  \
# datetime
# 2014-04-08 18:00:00                    943.00275   -0.000191    -0.00001
#
#                      Global TUVR [W/m^2]  Global 501A [W/m^2]  \
# datetime
# 2014-04-08 18:00:00               50.754              1.37285
#
#                      Global 501A [MED/hr]  Global MS210W [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                3.3109               1.237983
#
#                      Global CUVA1 [W/m^2]  Global CUVB1 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00               49.9995              1.373267
#
#                      Global UV-S-A-T [W/m^2]  Global UV-S-B-T [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                   50.711                 1.246467
#
#                      Global UVB-1 [W/m^2]  Global 501A [Index]  \
# datetime
# 2014-04-08 18:00:00              1.358683              7.67155
#
#                      Direct NIP #1 [W/m^2]  Direct NIP #2 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00              1023.7965            1026.984167
#
#                      Direct LI-201 [W/m^2]  Direct RG780 NIP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00             914.375767                379.984217
#
#                      Direct CH1 [W/m^2]  Zebra PSP (cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00         1021.293833               409.131733
#
#                      Direct CUVA2 [W/m^2]  Direct CUVB2 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00             42.254833              0.930933
#
#                      500nm TWC Photometer [V]  Global SPN1 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                  2.884389             942.2974
#
#                      Diffuse SPN1 [W/m^2]  Data lab Dry Bulb Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00             83.973732                       21.765667
#
#                      Data lab RH [%]  Diffuse PSP (sband/cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00        22.036333                        73.130863
#
#                      Research F1  Diffuse 8-48 (vent) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00   935.119968                    85.453185
#
#                      Diffuse CM22 (vent/cor) [W/m^2]  Research F0  Research 3  \
# datetime
# 2014-04-08 18:00:00                        81.610015    932.52747    0.000227
#
#                      Downwelling IR PIR Vent [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                         267.3415
#
#                      Downwelling IR CG4 Vent [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                         266.2866
#
#                      Upwelling IR PIR [W/m^2]  Instrument Net DW PIR [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                481.123633                      -157.8568
#
#                      Instrument Net DW CG4 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                    -132.399817
#
#                      Instrument Net UW PIR [W/m^2]  Global PSP (cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                       65.56608                 939.60165
#
#                      Global PSP (vent/cor) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                     935.470933
#
#                      Diffuse PSP (vent/cor) [W/m^2]  Diffuse CUV4 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                       79.239638               15.6105
#
#                      Global CUV4 [W/m^2]  Avg Wind Speed @ 19ft [m/s]  \
# datetime
# 2014-04-08 18:00:00              51.7305                     3.943483
#
#                      Avg Wind Direction @ 19ft [deg from N]  \
# datetime
# 2014-04-08 18:00:00                              279.018333
#
#                      Peak Wind Speed @ 19ft [m/s]  Direct MS-56 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                      5.408333           1026.810333
#
#                      Research 4  PIR DW Dome Temp [deg K]  \
# datetime
# 2014-04-08 18:00:00   -0.000072                293.427333
#
#                      PIR DW Case Temp [deg K]  CG4 DW Case Temp [deg K]  \
# datetime
# 2014-04-08 18:00:00                293.973167                290.509567
#
#                      PIR UW Dome Temp [deg K]  PIR UW Case Temp [deg K]  \
# datetime
# 2014-04-08 18:00:00                 293.17225                  292.8497
#
#                      CR3000 Temp [deg C]  Deck Dry Bulb Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00            22.267833                   16.994333
#
#                      Deck RH [%]  501A Temp [deg C]  CUVA1 Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00    17.858667          24.809833           39.888667
#
#                      CUVB1 Temp [deg C]  CUVA2 Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00           39.872167           40.673333
#
#                      CUVB2 Temp [deg C]  UVSAT Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00           39.718333           25.337167
#
#                      UVSBT Temp [deg C]  UVB-1 Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00           24.938667           46.704667
#
#                      Horiz TP Thermal Corr  CR3000 Battery [VDC]  \
# datetime
# 2014-04-08 18:00:00                      1                 13.06
#
#                      CR3000 Pgm Time [s]  Direct Quantum LI-190 [umol/s/m^2]  \
# datetime
# 2014-04-08 18:00:00             2.691583                         1989.468333
#
#                      Direct TUVR [W/m^2]  Global PSP [mV]  \
# datetime
# 2014-04-08 18:00:00            46.356522         8.248512
#
#                      Global PSP Vent [mV]  Global CM22 [mV]  \
# datetime
# 2014-04-08 18:00:00               6.37114          10.20603
#
#                      Global RG780 PSP [mV]  Global CM6b [mV]  Zebra PSP [mV]  \
# datetime
# 2014-04-08 18:00:00               3.235135         10.197693         3.46243
#
#                      Diffuse PSP (sband) [mV]  Diffuse PSP [mV]  \
# datetime
# 2014-04-08 18:00:00                  0.500048          0.458301
#
#                      Diffuse CM22 [mV]  Global Quantum LI-190 [umol/s/m^2]  \
# datetime
# 2014-04-08 18:00:00           0.782364                           1865.9175
#
#                      Global Photometric LI-210 [klux]  \
# datetime
# 2014-04-08 18:00:00                         86.709267
#
#                      Upwelling Shortwave CM3 (CNR1) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                              153.300767
#
#                      Upwelling IR CG3 (CNR1) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                       478.643117
#
#                      Instrument Net UW CG3 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                      54.288468
#
#                      Upwelling Shortwave PSP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                       157.641833
#
#                      Upwelling Shortwave LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                           176.65235
#
#                      Upwelling Quantum LI-190 [umol/s/m^2]  \
# datetime
# 2014-04-08 18:00:00                               192.9123
#
#                      CNR1 Case Temp [deg K]  Global CM3 (CNR1) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00              293.016467                 949.084733
#
#                      Downwelling IR CG3 (CNR1) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                         278.188317
#
#                      Instrument Net DW CG3 [W/m^2]  Snow Depth [cm]  \
# datetime
# 2014-04-08 18:00:00                    -137.669567         0.092433
#
#                      Precipitation [mm]  Precipitation (Accumulated) [mm]  \
# datetime
# 2014-04-08 18:00:00                   0                                 0
#
#                      Station Pressure [mBar]  Global 40-South PSP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00               820.982533                    1130.6985
#
#                      Global 40-South LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                     1143.429667
#
#                      Global Normal CM-21 [W/m^2]  Global 90-North PSP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                  1127.725333                   130.252933
#
#                      Global 90-North LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                      127.781417
#
#                      Global 90-East PSP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                  251.647117
#
#                      Global 90-East LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                       270.2357
#
#                      Global 90-South PSP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                      637.613
#
#                      Global 90-South LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                       684.48425
#
#                      Global 90-West PSP [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                    122.0807
#
#                      Global 90-West LI-200 [W/m^2]  Research RT0  \
# datetime
# 2014-04-08 18:00:00                      130.02505             0
#
#                      Research RT1  Research RT2  \
# datetime
# 2014-04-08 18:00:00             0             0
#
#                      Atmospheric Electric Field [kV/m]  \
# datetime
# 2014-04-08 18:00:00                           0.066503
#
#                      CR10X Temp (Rad-Twr) [deg C]  \
# datetime
# 2014-04-08 18:00:00                       22.5315
#
#                      CR10X Battery (Rad-Twr) [VDC]  LI-2020 Battery [VDC]  \
# datetime
# 2014-04-08 18:00:00                      13.347167                21.2205
#
#                      Tower Dry Bulb Temp [deg C]  Tower RH [%]  \
# datetime
# 2014-04-08 18:00:00                      17.0165     19.134833
#
#                      Avg Wind Speed @ 6ft [m/s]  \
# datetime
# 2014-04-08 18:00:00                       2.888
#
#                      Avg Wind Direction @ 6ft [deg from N]  \
# datetime
# 2014-04-08 18:00:00                             277.266683
#
#                      Peak Wind Speed @ 6ft [m/s]  \
# datetime
# 2014-04-08 18:00:00                     4.370833
#
#                      CR10X Overuns (Rad-Twr) [counts]  Snow Depth Quality  \
# datetime
# 2014-04-08 18:00:00                                 0          193.901667
#
#                      SE Dry Bulb Temp [deg C]  SE RH [%]  \
# datetime
# 2014-04-08 18:00:00                 16.804667    18.1875
#
#                      SE-POA Angle [degrees]  Global SE-POA LI-200 [W/m^2]  \
# datetime
# 2014-04-08 18:00:00               -9.005767                    953.134867
#
#                      CR10X Overuns (Met-Twr) [counts]  \
# datetime
# 2014-04-08 18:00:00                                 0
#
#                      CR10X Temp (Met-Twr) [deg C]  \
# datetime
# 2014-04-08 18:00:00                     20.379833
#
#                      CR10X Battery (Met-Twr) [VDC]  Vertical Wind Shear [1/s]  \
# datetime
# 2014-04-08 18:00:00                        13.2005                    0.04065
#
#                      Research PVT1  Research PVT2  \
# datetime
# 2014-04-08 18:00:00              0              0
#
#                      Avg Wind Speed @ 22ft [m/s]  \
# datetime
# 2014-04-08 18:00:00                     4.819667
#
#                      Avg Wind Direction @ 22ft [deg from N]  \
# datetime
# 2014-04-08 18:00:00                              282.896667
#
#                      Avg Wind Speed @ 42ft [m/s]  \
# datetime
# 2014-04-08 18:00:00                     5.067683
#
#                      Avg Wind Direction @ 42ft [deg from N]  Research PVT0  \
# datetime
# 2014-04-08 18:00:00                              284.631667              0
#
#                      Peak Wind Speed @ 22ft [m/s]  \
# datetime
# 2014-04-08 18:00:00                      6.508667
#
#                      Peak Wind Speed @ 42ft [m/s]  Delta UT1 [seconds]  \
# datetime
# 2014-04-08 18:00:00                      6.646217                  0.1
#
#                      500nm TWC AOD  Net Radiation Eppley [W/m^2]  \
# datetime
# 2014-04-08 18:00:00       0.460351                    564.046967
#
#                      Net Radiation K&Z [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                 574.143133
#
#                      Atmos Net Infrared PIRs [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                      -213.782133
#
#                      Atmos Net Infrared K&Zs [W/m^2]  Albedo (PSP)  \
# datetime
# 2014-04-08 18:00:00                      -212.356517      0.168522
#
#                      Albedo (K&Z)  Albedo (LI-200)  Albedo Quantum (LI-190)  \
# datetime
# 2014-04-08 18:00:00      0.163112         0.186888                 0.103387
#
#                      Broadband Turbidity  500nm Estimated AOD  \
# datetime
# 2014-04-08 18:00:00             0.067944              0.14291
#
#                      Sea-Level Pressure (Est) [mBar]  \
# datetime
# 2014-04-08 18:00:00                        1022.2585
#
#                      Tower Dew Point Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00                     -5.922083
#
#                      Tower Wet Bulb Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00                     6.315917
#
#                      Tower Wind Chill Temp [deg C]  \
# datetime
# 2014-04-08 18:00:00                      16.906617
#
#                      Deck Wind Chill Temp [deg C]  Total Cloud Cover [%]  \
# datetime
# 2014-04-08 18:00:00                     16.657217               0.316667
#
#                      Opaque Cloud Cover [%]  \
# datetime
# 2014-04-08 18:00:00                0.283333
#
#                      Global Extraterrestrial (calc) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                             1137.935067
#
#                      Direct Extraterrestrial (calc) [W/m^2]  \
# datetime
# 2014-04-08 18:00:00                             1363.283783
#
#                      Zenith Angle [degrees]  Azimuth Angle [degrees]  \
# datetime
# 2014-04-08 18:00:00               33.404983               165.102404
#
#                       Airmass  Delta T [seconds]  \
# datetime
# 2014-04-08 18:00:00  1.197326             67.084
#
#                      315nm POM-01 Photometer [nA]  \
# datetime
# 2014-04-08 18:00:00                  -2194.917883
#
#                      400nm POM-01 Photometer [uA]  \
# datetime
# 2014-04-08 18:00:00                  -2179.650583
#
#                      500nm POM-01 Photometer [uA]  \
# datetime
# 2014-04-08 18:00:00                  -2065.379667
#
#                      675nm POM-01 Photometer [uA]  \
# datetime
# 2014-04-08 18:00:00                    -2005.4225
#
#                      870nm POM-01 Photometer [uA]  \
# datetime
# 2014-04-08 18:00:00                  -2060.177167
#
#                      940nm POM-01 Photometer [uA]  \
# datetime
# 2014-04-08 18:00:00                  -2117.088833
#
#                      1020nm POM-01 Photometer [uA]  315nm Obsolete AOD  \
# datetime
# 2014-04-08 18:00:00                   -2093.865833         -2216.45358
#
#                      400nm Obsolete AOD  500nm Obsolete AOD  \
# datetime
# 2014-04-08 18:00:00        -2216.194319         -2216.29417
#
#                      675nm Obsolete AOD  870nm Obsolete AOD  \
# datetime
# 2014-04-08 18:00:00        -2216.333306        -2216.345249
#
#                      940nm Obsolete AOD  1020nm Obsolete AOD  Research F2
# datetime
# 2014-04-08 18:00:00        -2216.202907         -2216.346496    87.310388
#                             Power
# datetime
# 2014-04-08 18:00:00  12472.833333

# %%
#Gather data for predicting power from sensor data
#...by building another data frame?
print df_sensor[df_sensor.index == desired_datetime].values[0]
print df_pvoutput[df_pvoutput.index == desired_datetime].values[0][0]
# Out:
# [  0.00000000e+00   2.01400000e+03   9.80000000e+01   0.00000000e+00
#    3.34037567e+01   9.45304717e+02   9.39800417e+02   3.93684100e+02
#    9.60874000e+02   9.38801000e+02   9.22593950e+02   8.97575617e+02
#    9.43002750e+02  -1.90566667e-04  -9.73333333e-06   5.07540000e+01
#    1.37285000e+00   3.31090000e+00   1.23798333e+00   4.99995000e+01
#    1.37326667e+00   5.07110000e+01   1.24646667e+00   1.35868333e+00
#    7.67155000e+00   1.02379650e+03   1.02698417e+03   9.14375767e+02
#    3.79984217e+02   1.02129383e+03   4.09131733e+02   4.22548333e+01
#    9.30933333e-01   2.88438857e+00   9.42297400e+02   8.39737317e+01
#    2.17656667e+01   2.20363333e+01   7.31308633e+01   9.35119968e+02
#    8.54531850e+01   8.16100150e+01   9.32527470e+02   2.27266667e-04
#    2.67341500e+02   2.66286600e+02   4.81123633e+02  -1.57856800e+02
#   -1.32399817e+02   6.55660800e+01   9.39601650e+02   9.35470933e+02
#    7.92396383e+01   1.56105000e+01   5.17305000e+01   3.94348333e+00
#    2.79018333e+02   5.40833333e+00   1.02681033e+03  -7.21166667e-05
#    2.93427333e+02   2.93973167e+02   2.90509567e+02   2.93172250e+02
#    2.92849700e+02   2.22678333e+01   1.69943333e+01   1.78586667e+01
#    2.48098333e+01   3.98886667e+01   3.98721667e+01   4.06733333e+01
#    3.97183333e+01   2.53371667e+01   2.49386667e+01   4.67046667e+01
#    1.00000000e+00   1.30600000e+01   2.69158333e+00   1.98946833e+03
#    4.63565217e+01   8.24851200e+00   6.37114000e+00   1.02060297e+01
#    3.23513483e+00   1.01976930e+01   3.46243027e+00   5.00048317e-01
#    4.58300900e-01   7.82364183e-01   1.86591750e+03   8.67092667e+01
#    1.53300767e+02   4.78643117e+02   5.42884683e+01   1.57641833e+02
#    1.76652350e+02   1.92912300e+02   2.93016467e+02   9.49084733e+02
#    2.78188317e+02  -1.37669567e+02   9.24333333e-02   0.00000000e+00
#    0.00000000e+00   8.20982533e+02   1.13069850e+03   1.14342967e+03
#    1.12772533e+03   1.30252933e+02   1.27781417e+02   2.51647117e+02
#    2.70235700e+02   6.37613000e+02   6.84484250e+02   1.22080700e+02
#    1.30025050e+02   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    6.65025833e-02   2.25315000e+01   1.33471667e+01   2.12205000e+01
#    1.70165000e+01   1.91348333e+01   2.88800000e+00   2.77266683e+02
#    4.37083333e+00   0.00000000e+00   1.93901667e+02   1.68046667e+01
#    1.81875000e+01  -9.00576667e+00   9.53134867e+02   0.00000000e+00
#    2.03798333e+01   1.32005000e+01   4.06500000e-02   0.00000000e+00
#    0.00000000e+00   4.81966667e+00   2.82896667e+02   5.06768333e+00
#    2.84631667e+02   0.00000000e+00   6.50866667e+00   6.64621667e+00
#    1.00000000e-01   4.60351167e-01   5.64046967e+02   5.74143133e+02
#   -2.13782133e+02  -2.12356517e+02   1.68521667e-01   1.63111667e-01
#    1.86888333e-01   1.03386667e-01   6.79440000e-02   1.42910167e-01
#    1.02225850e+03  -5.92208333e+00   6.31591667e+00   1.69066167e+01
#    1.66572167e+01   3.16666667e-01   2.83333333e-01   1.13793507e+03
#    1.36328378e+03   3.34049833e+01   1.65102404e+02   1.19732617e+00
#    6.70840000e+01  -2.19491788e+03  -2.17965058e+03  -2.06537967e+03
#   -2.00542250e+03  -2.06017717e+03  -2.11708883e+03  -2.09386583e+03
#   -2.21645358e+03  -2.21619432e+03  -2.21629417e+03  -2.21633331e+03
#   -2.21634525e+03  -2.21620291e+03  -2.21634650e+03   8.73103883e+01]
# 12472.8333333

# %%
#iterate over datetimes:
time = datetime(2014, 4, 1, 13)
make_time(time)
# Out:
# [datetime.datetime(2014, 4, 1, 13, 0),
#  datetime.datetime(2014, 4, 1, 14, 0),
#  datetime.datetime(2014, 4, 1, 15, 0),
#  datetime.datetime(2014, 4, 1, 16, 0),
#  datetime.datetime(2014, 4, 1, 17, 0),
#  datetime.datetime(2014, 4, 1, 18, 0),
#  datetime.datetime(2014, 4, 1, 19, 0),
#  datetime.datetime(2014, 4, 1, 20, 0),
#  datetime.datetime(2014, 4, 1, 21, 0),
#  datetime.datetime(2014, 4, 1, 22, 0),
#  datetime.datetime(2014, 4, 1, 23, 0),
#  datetime.datetime(2014, 4, 2, 0, 0),
#  datetime.datetime(2014, 4, 2, 1, 0),
#  datetime.datetime(2014, 4, 2, 2, 0),
#  datetime.datetime(2014, 4, 2, 3, 0),
#  datetime.datetime(2014, 4, 2, 13, 0),
#  datetime.datetime(2014, 4, 2, 14, 0),
#  datetime.datetime(2014, 4, 2, 15, 0),
#  datetime.datetime(2014, 4, 2, 16, 0),
#  datetime.datetime(2014, 4, 2, 17, 0),
#  datetime.datetime(2014, 4, 2, 18, 0),
#  datetime.datetime(2014, 4, 2, 19, 0),
#  datetime.datetime(2014, 4, 2, 20, 0),
#  datetime.datetime(2014, 4, 2, 21, 0),
#  datetime.datetime(2014, 4, 2, 22, 0),
#  datetime.datetime(2014, 4, 2, 23, 0),
#  datetime.datetime(2014, 4, 3, 0, 0),
#  datetime.datetime(2014, 4, 3, 1, 0),
#  datetime.datetime(2014, 4, 3, 2, 0),
#  datetime.datetime(2014, 4, 3, 3, 0),
#  datetime.datetime(2014, 4, 3, 13, 0),
#  datetime.datetime(2014, 4, 3, 14, 0),
#  datetime.datetime(2014, 4, 3, 15, 0),
#  datetime.datetime(2014, 4, 3, 16, 0),
#  datetime.datetime(2014, 4, 3, 17, 0),
#  datetime.datetime(2014, 4, 3, 18, 0),
#  datetime.datetime(2014, 4, 3, 19, 0),
#  datetime.datetime(2014, 4, 3, 20, 0),
#  datetime.datetime(2014, 4, 3, 21, 0),
#  datetime.datetime(2014, 4, 3, 22, 0),
#  datetime.datetime(2014, 4, 3, 23, 0),
#  datetime.datetime(2014, 4, 4, 0, 0),
#  datetime.datetime(2014, 4, 4, 1, 0),
#  datetime.datetime(2014, 4, 4, 2, 0),
#  datetime.datetime(2014, 4, 4, 3, 0),
#  datetime.datetime(2014, 4, 4, 13, 0),
#  datetime.datetime(2014, 4, 4, 14, 0),
#  datetime.datetime(2014, 4, 4, 15, 0),
#  datetime.datetime(2014, 4, 4, 16, 0),
#  datetime.datetime(2014, 4, 4, 17, 0),
#  datetime.datetime(2014, 4, 4, 18, 0),
#  datetime.datetime(2014, 4, 4, 19, 0),
#  datetime.datetime(2014, 4, 4, 20, 0),
#  datetime.datetime(2014, 4, 4, 21, 0),
#  datetime.datetime(2014, 4, 4, 22, 0),
#  datetime.datetime(2014, 4, 4, 23, 0),
#  datetime.datetime(2014, 4, 5, 0, 0),
#  datetime.datetime(2014, 4, 5, 1, 0),
#  datetime.datetime(2014, 4, 5, 2, 0),
#  datetime.datetime(2014, 4, 5, 3, 0),
#  datetime.datetime(2014, 4, 5, 13, 0),
#  datetime.datetime(2014, 4, 5, 14, 0),
#  datetime.datetime(2014, 4, 5, 15, 0),
#  datetime.datetime(2014, 4, 5, 16, 0),
#  datetime.datetime(2014, 4, 5, 17, 0),
#  datetime.datetime(2014, 4, 5, 18, 0),
#  datetime.datetime(2014, 4, 5, 19, 0),
#  datetime.datetime(2014, 4, 5, 20, 0),
#  datetime.datetime(2014, 4, 5, 21, 0),
#  datetime.datetime(2014, 4, 5, 22, 0),
#  datetime.datetime(2014, 4, 5, 23, 0),
#  datetime.datetime(2014, 4, 6, 0, 0),
#  datetime.datetime(2014, 4, 6, 1, 0),
#  datetime.datetime(2014, 4, 6, 2, 0),
#  datetime.datetime(2014, 4, 6, 3, 0),
#  datetime.datetime(2014, 4, 6, 13, 0),
#  datetime.datetime(2014, 4, 6, 14, 0),
#  datetime.datetime(2014, 4, 6, 15, 0),
#  datetime.datetime(2014, 4, 6, 16, 0),
#  datetime.datetime(2014, 4, 6, 17, 0),
#  datetime.datetime(2014, 4, 6, 18, 0),
#  datetime.datetime(2014, 4, 6, 19, 0),
#  datetime.datetime(2014, 4, 6, 20, 0),
#  datetime.datetime(2014, 4, 6, 21, 0),
#  datetime.datetime(2014, 4, 6, 22, 0),
#  datetime.datetime(2014, 4, 6, 23, 0),
#  datetime.datetime(2014, 4, 7, 0, 0),
#  datetime.datetime(2014, 4, 7, 1, 0),
#  datetime.datetime(2014, 4, 7, 2, 0),
#  datetime.datetime(2014, 4, 7, 3, 0),
#  datetime.datetime(2014, 4, 7, 13, 0),
#  datetime.datetime(2014, 4, 7, 14, 0),
#  datetime.datetime(2014, 4, 7, 15, 0),
#  datetime.datetime(2014, 4, 7, 16, 0),
#  datetime.datetime(2014, 4, 7, 17, 0),
#  datetime.datetime(2014, 4, 7, 18, 0),
#  datetime.datetime(2014, 4, 7, 19, 0),
#  datetime.datetime(2014, 4, 7, 20, 0),
#  datetime.datetime(2014, 4, 7, 21, 0),
#  datetime.datetime(2014, 4, 7, 22, 0),
#  datetime.datetime(2014, 4, 7, 23, 0),
#  datetime.datetime(2014, 4, 8, 0, 0),
#  datetime.datetime(2014, 4, 8, 1, 0),
#  datetime.datetime(2014, 4, 8, 2, 0),
#  datetime.datetime(2014, 4, 8, 3, 0),
#  datetime.datetime(2014, 4, 8, 13, 0),
#  datetime.datetime(2014, 4, 8, 14, 0),
#  datetime.datetime(2014, 4, 8, 15, 0),
#  datetime.datetime(2014, 4, 8, 16, 0),
#  datetime.datetime(2014, 4, 8, 17, 0),
#  datetime.datetime(2014, 4, 8, 18, 0),
#  datetime.datetime(2014, 4, 8, 19, 0),
#  datetime.datetime(2014, 4, 8, 20, 0),
#  datetime.datetime(2014, 4, 8, 21, 0),
#  datetime.datetime(2014, 4, 8, 22, 0),
#  datetime.datetime(2014, 4, 8, 23, 0),
#  datetime.datetime(2014, 4, 9, 0, 0),
#  datetime.datetime(2014, 4, 9, 1, 0),
#  datetime.datetime(2014, 4, 9, 2, 0),
#  datetime.datetime(2014, 4, 9, 3, 0),
#  datetime.datetime(2014, 4, 9, 13, 0),
#  datetime.datetime(2014, 4, 9, 14, 0),
#  datetime.datetime(2014, 4, 9, 15, 0),
#  datetime.datetime(2014, 4, 9, 16, 0),
#  datetime.datetime(2014, 4, 9, 17, 0),
#  datetime.datetime(2014, 4, 9, 18, 0),
#  datetime.datetime(2014, 4, 9, 19, 0),
#  datetime.datetime(2014, 4, 9, 20, 0),
#  datetime.datetime(2014, 4, 9, 21, 0),
#  datetime.datetime(2014, 4, 9, 22, 0),
#  datetime.datetime(2014, 4, 9, 23, 0),
#  datetime.datetime(2014, 4, 10, 0, 0),
#  datetime.datetime(2014, 4, 10, 1, 0),
#  datetime.datetime(2014, 4, 10, 2, 0),
#  datetime.datetime(2014, 4, 10, 3, 0),
#  datetime.datetime(2014, 4, 10, 13, 0),
#  datetime.datetime(2014, 4, 10, 14, 0),
#  datetime.datetime(2014, 4, 10, 15, 0),
#  datetime.datetime(2014, 4, 10, 16, 0),
#  datetime.datetime(2014, 4, 10, 17, 0),
#  datetime.datetime(2014, 4, 10, 18, 0),
#  datetime.datetime(2014, 4, 10, 19, 0),
#  datetime.datetime(2014, 4, 10, 20, 0),
#  datetime.datetime(2014, 4, 10, 21, 0),
#  datetime.datetime(2014, 4, 10, 22, 0),
#  datetime.datetime(2014, 4, 10, 23, 0),
#  datetime.datetime(2014, 4, 11, 0, 0),
#  datetime.datetime(2014, 4, 11, 1, 0),
#  datetime.datetime(2014, 4, 11, 2, 0),
#  datetime.datetime(2014, 4, 11, 3, 0),
#  datetime.datetime(2014, 4, 11, 13, 0),
#  datetime.datetime(2014, 4, 11, 14, 0),
#  datetime.datetime(2014, 4, 11, 15, 0),
#  datetime.datetime(2014, 4, 11, 16, 0),
#  datetime.datetime(2014, 4, 11, 17, 0),
#  datetime.datetime(2014, 4, 11, 18, 0),
#  datetime.datetime(2014, 4, 11, 19, 0),
#  datetime.datetime(2014, 4, 11, 20, 0),
#  datetime.datetime(2014, 4, 11, 21, 0),
#  datetime.datetime(2014, 4, 11, 22, 0),
#  datetime.datetime(2014, 4, 11, 23, 0),
#  datetime.datetime(2014, 4, 12, 0, 0),
#  datetime.datetime(2014, 4, 12, 1, 0),
#  datetime.datetime(2014, 4, 12, 2, 0),
#  datetime.datetime(2014, 4, 12, 3, 0),
#  datetime.datetime(2014, 4, 12, 13, 0),
#  datetime.datetime(2014, 4, 12, 14, 0),
#  datetime.datetime(2014, 4, 12, 15, 0),
#  datetime.datetime(2014, 4, 12, 16, 0),
#  datetime.datetime(2014, 4, 12, 17, 0),
#  datetime.datetime(2014, 4, 12, 18, 0),
#  datetime.datetime(2014, 4, 12, 19, 0),
#  datetime.datetime(2014, 4, 12, 20, 0),
#  datetime.datetime(2014, 4, 12, 21, 0),
#  datetime.datetime(2014, 4, 12, 22, 0),
#  datetime.datetime(2014, 4, 12, 23, 0),
#  datetime.datetime(2014, 4, 13, 0, 0),
#  datetime.datetime(2014, 4, 13, 1, 0),
#  datetime.datetime(2014, 4, 13, 2, 0),
#  datetime.datetime(2014, 4, 13, 3, 0),
#  datetime.datetime(2014, 4, 13, 13, 0),
#  datetime.datetime(2014, 4, 13, 14, 0),
#  datetime.datetime(2014, 4, 13, 15, 0),
#  datetime.datetime(2014, 4, 13, 16, 0),
#  datetime.datetime(2014, 4, 13, 17, 0),
#  datetime.datetime(2014, 4, 13, 18, 0),
#  datetime.datetime(2014, 4, 13, 19, 0),
#  datetime.datetime(2014, 4, 13, 20, 0),
#  datetime.datetime(2014, 4, 13, 21, 0),
#  datetime.datetime(2014, 4, 13, 22, 0),
#  datetime.datetime(2014, 4, 13, 23, 0),
#  datetime.datetime(2014, 4, 14, 0, 0),
#  datetime.datetime(2014, 4, 14, 1, 0),
#  datetime.datetime(2014, 4, 14, 2, 0),
#  datetime.datetime(2014, 4, 14, 3, 0),
#  datetime.datetime(2014, 4, 14, 13, 0),
#  datetime.datetime(2014, 4, 14, 14, 0),
#  datetime.datetime(2014, 4, 14, 15, 0),
#  datetime.datetime(2014, 4, 14, 16, 0),
#  datetime.datetime(2014, 4, 14, 17, 0),
#  datetime.datetime(2014, 4, 14, 18, 0),
#  datetime.datetime(2014, 4, 14, 19, 0),
#  datetime.datetime(2014, 4, 14, 20, 0),
#  datetime.datetime(2014, 4, 14, 21, 0),
#  datetime.datetime(2014, 4, 14, 22, 0),
#  datetime.datetime(2014, 4, 14, 23, 0),
#  datetime.datetime(2014, 4, 15, 0, 0),
#  datetime.datetime(2014, 4, 15, 1, 0),
#  datetime.datetime(2014, 4, 15, 2, 0),
#  datetime.datetime(2014, 4, 15, 3, 0),
#  datetime.datetime(2014, 4, 15, 13, 0),
#  datetime.datetime(2014, 4, 15, 14, 0),
#  datetime.datetime(2014, 4, 15, 15, 0),
#  datetime.datetime(2014, 4, 15, 16, 0),
#  datetime.datetime(2014, 4, 15, 17, 0),
#  datetime.datetime(2014, 4, 15, 18, 0),
#  datetime.datetime(2014, 4, 15, 19, 0),
#  datetime.datetime(2014, 4, 15, 20, 0),
#  datetime.datetime(2014, 4, 15, 21, 0),
#  datetime.datetime(2014, 4, 15, 22, 0),
#  datetime.datetime(2014, 4, 15, 23, 0),
#  datetime.datetime(2014, 4, 16, 0, 0),
#  datetime.datetime(2014, 4, 16, 1, 0),
#  datetime.datetime(2014, 4, 16, 2, 0),
#  datetime.datetime(2014, 4, 16, 3, 0),
#  datetime.datetime(2014, 4, 16, 13, 0),
#  datetime.datetime(2014, 4, 16, 14, 0),
#  datetime.datetime(2014, 4, 16, 15, 0),
#  datetime.datetime(2014, 4, 16, 16, 0),
#  datetime.datetime(2014, 4, 16, 17, 0),
#  datetime.datetime(2014, 4, 16, 18, 0),
#  datetime.datetime(2014, 4, 16, 19, 0),
#  datetime.datetime(2014, 4, 16, 20, 0),
#  datetime.datetime(2014, 4, 16, 21, 0),
#  datetime.datetime(2014, 4, 16, 22, 0),
#  datetime.datetime(2014, 4, 16, 23, 0),
#  datetime.datetime(2014, 4, 17, 0, 0),
#  datetime.datetime(2014, 4, 17, 1, 0),
#  datetime.datetime(2014, 4, 17, 2, 0),
#  datetime.datetime(2014, 4, 17, 3, 0),
#  datetime.datetime(2014, 4, 17, 13, 0),
#  datetime.datetime(2014, 4, 17, 14, 0),
#  datetime.datetime(2014, 4, 17, 15, 0),
#  datetime.datetime(2014, 4, 17, 16, 0),
#  datetime.datetime(2014, 4, 17, 17, 0),
#  datetime.datetime(2014, 4, 17, 18, 0),
#  datetime.datetime(2014, 4, 17, 19, 0),
#  datetime.datetime(2014, 4, 17, 20, 0),
#  datetime.datetime(2014, 4, 17, 21, 0),
#  datetime.datetime(2014, 4, 17, 22, 0),
#  datetime.datetime(2014, 4, 17, 23, 0),
#  datetime.datetime(2014, 4, 18, 0, 0),
#  datetime.datetime(2014, 4, 18, 1, 0),
#  datetime.datetime(2014, 4, 18, 2, 0),
#  datetime.datetime(2014, 4, 18, 3, 0),
#  datetime.datetime(2014, 4, 18, 13, 0),
#  datetime.datetime(2014, 4, 18, 14, 0),
#  datetime.datetime(2014, 4, 18, 15, 0),
#  datetime.datetime(2014, 4, 18, 16, 0),
#  datetime.datetime(2014, 4, 18, 17, 0),
#  datetime.datetime(2014, 4, 18, 18, 0),
#  datetime.datetime(2014, 4, 18, 19, 0),
#  datetime.datetime(2014, 4, 18, 20, 0),
#  datetime.datetime(2014, 4, 18, 21, 0),
#  datetime.datetime(2014, 4, 18, 22, 0),
#  datetime.datetime(2014, 4, 18, 23, 0),
#  datetime.datetime(2014, 4, 19, 0, 0),
#  datetime.datetime(2014, 4, 19, 1, 0),
#  datetime.datetime(2014, 4, 19, 2, 0),
#  datetime.datetime(2014, 4, 19, 3, 0),
#  datetime.datetime(2014, 4, 19, 13, 0),
#  datetime.datetime(2014, 4, 19, 14, 0),
#  datetime.datetime(2014, 4, 19, 15, 0),
#  datetime.datetime(2014, 4, 19, 16, 0),
#  datetime.datetime(2014, 4, 19, 17, 0),
#  datetime.datetime(2014, 4, 19, 18, 0),
#  datetime.datetime(2014, 4, 19, 19, 0),
#  datetime.datetime(2014, 4, 19, 20, 0),
#  datetime.datetime(2014, 4, 19, 21, 0),
#  datetime.datetime(2014, 4, 19, 22, 0),
#  datetime.datetime(2014, 4, 19, 23, 0),
#  datetime.datetime(2014, 4, 20, 0, 0),
#  datetime.datetime(2014, 4, 20, 1, 0),
#  datetime.datetime(2014, 4, 20, 2, 0),
#  datetime.datetime(2014, 4, 20, 3, 0),
#  datetime.datetime(2014, 4, 20, 13, 0),
#  datetime.datetime(2014, 4, 20, 14, 0),
#  datetime.datetime(2014, 4, 20, 15, 0),
#  datetime.datetime(2014, 4, 20, 16, 0),
#  datetime.datetime(2014, 4, 20, 17, 0),
#  datetime.datetime(2014, 4, 20, 18, 0),
#  datetime.datetime(2014, 4, 20, 19, 0),
#  datetime.datetime(2014, 4, 20, 20, 0),
#  datetime.datetime(2014, 4, 20, 21, 0),
#  datetime.datetime(2014, 4, 20, 22, 0),
#  datetime.datetime(2014, 4, 20, 23, 0),
#  datetime.datetime(2014, 4, 21, 0, 0),
#  datetime.datetime(2014, 4, 21, 1, 0),
#  datetime.datetime(2014, 4, 21, 2, 0),
#  datetime.datetime(2014, 4, 21, 3, 0),
#  datetime.datetime(2014, 4, 21, 13, 0),
#  datetime.datetime(2014, 4, 21, 14, 0),
#  datetime.datetime(2014, 4, 21, 15, 0),
#  datetime.datetime(2014, 4, 21, 16, 0),
#  datetime.datetime(2014, 4, 21, 17, 0),
#  datetime.datetime(2014, 4, 21, 18, 0),
#  datetime.datetime(2014, 4, 21, 19, 0),
#  datetime.datetime(2014, 4, 21, 20, 0),
#  datetime.datetime(2014, 4, 21, 21, 0),
#  datetime.datetime(2014, 4, 21, 22, 0),
#  datetime.datetime(2014, 4, 21, 23, 0),
#  datetime.datetime(2014, 4, 22, 0, 0),
#  datetime.datetime(2014, 4, 22, 1, 0),
#  datetime.datetime(2014, 4, 22, 2, 0),
#  datetime.datetime(2014, 4, 22, 3, 0),
#  datetime.datetime(2014, 4, 22, 13, 0),
#  datetime.datetime(2014, 4, 22, 14, 0),
#  datetime.datetime(2014, 4, 22, 15, 0),
#  datetime.datetime(2014, 4, 22, 16, 0),
#  datetime.datetime(2014, 4, 22, 17, 0),
#  datetime.datetime(2014, 4, 22, 18, 0),
#  datetime.datetime(2014, 4, 22, 19, 0),
#  datetime.datetime(2014, 4, 22, 20, 0),
#  datetime.datetime(2014, 4, 22, 21, 0),
#  datetime.datetime(2014, 4, 22, 22, 0),
#  datetime.datetime(2014, 4, 22, 23, 0),
#  datetime.datetime(2014, 4, 23, 0, 0),
#  datetime.datetime(2014, 4, 23, 1, 0),
#  datetime.datetime(2014, 4, 23, 2, 0),
#  datetime.datetime(2014, 4, 23, 3, 0),
#  datetime.datetime(2014, 4, 23, 13, 0),
#  datetime.datetime(2014, 4, 23, 14, 0),
#  datetime.datetime(2014, 4, 23, 15, 0),
#  datetime.datetime(2014, 4, 23, 16, 0),
#  datetime.datetime(2014, 4, 23, 17, 0),
#  datetime.datetime(2014, 4, 23, 18, 0),
#  datetime.datetime(2014, 4, 23, 19, 0),
#  datetime.datetime(2014, 4, 23, 20, 0),
#  datetime.datetime(2014, 4, 23, 21, 0),
#  datetime.datetime(2014, 4, 23, 22, 0),
#  datetime.datetime(2014, 4, 23, 23, 0),
#  datetime.datetime(2014, 4, 24, 0, 0),
#  datetime.datetime(2014, 4, 24, 1, 0),
#  datetime.datetime(2014, 4, 24, 2, 0),
#  datetime.datetime(2014, 4, 24, 3, 0),
#  datetime.datetime(2014, 4, 24, 13, 0),
#  datetime.datetime(2014, 4, 24, 14, 0),
#  datetime.datetime(2014, 4, 24, 15, 0),
#  datetime.datetime(2014, 4, 24, 16, 0),
#  datetime.datetime(2014, 4, 24, 17, 0),
#  datetime.datetime(2014, 4, 24, 18, 0),
#  datetime.datetime(2014, 4, 24, 19, 0),
#  datetime.datetime(2014, 4, 24, 20, 0),
#  datetime.datetime(2014, 4, 24, 21, 0),
#  datetime.datetime(2014, 4, 24, 22, 0),
#  datetime.datetime(2014, 4, 24, 23, 0),
#  datetime.datetime(2014, 4, 25, 0, 0),
#  datetime.datetime(2014, 4, 25, 1, 0),
#  datetime.datetime(2014, 4, 25, 2, 0),
#  datetime.datetime(2014, 4, 25, 3, 0),
#  datetime.datetime(2014, 4, 25, 13, 0),
#  datetime.datetime(2014, 4, 25, 14, 0),
#  datetime.datetime(2014, 4, 25, 15, 0),
#  datetime.datetime(2014, 4, 25, 16, 0),
#  datetime.datetime(2014, 4, 25, 17, 0),
#  datetime.datetime(2014, 4, 25, 18, 0),
#  datetime.datetime(2014, 4, 25, 19, 0),
#  datetime.datetime(2014, 4, 25, 20, 0),
#  datetime.datetime(2014, 4, 25, 21, 0),
#  datetime.datetime(2014, 4, 25, 22, 0),
#  datetime.datetime(2014, 4, 25, 23, 0),
#  datetime.datetime(2014, 4, 26, 0, 0),
#  datetime.datetime(2014, 4, 26, 1, 0),
#  datetime.datetime(2014, 4, 26, 2, 0),
#  datetime.datetime(2014, 4, 26, 3, 0),
#  datetime.datetime(2014, 4, 26, 13, 0),
#  datetime.datetime(2014, 4, 26, 14, 0),
#  datetime.datetime(2014, 4, 26, 15, 0),
#  datetime.datetime(2014, 4, 26, 16, 0),
#  datetime.datetime(2014, 4, 26, 17, 0),
#  datetime.datetime(2014, 4, 26, 18, 0),
#  datetime.datetime(2014, 4, 26, 19, 0),
#  datetime.datetime(2014, 4, 26, 20, 0),
#  datetime.datetime(2014, 4, 26, 21, 0),
#  datetime.datetime(2014, 4, 26, 22, 0),
#  datetime.datetime(2014, 4, 26, 23, 0),
#  datetime.datetime(2014, 4, 27, 0, 0),
#  datetime.datetime(2014, 4, 27, 1, 0),
#  datetime.datetime(2014, 4, 27, 2, 0),
#  datetime.datetime(2014, 4, 27, 3, 0),
#  datetime.datetime(2014, 4, 27, 13, 0),
#  datetime.datetime(2014, 4, 27, 14, 0),
#  datetime.datetime(2014, 4, 27, 15, 0),
#  datetime.datetime(2014, 4, 27, 16, 0),
#  datetime.datetime(2014, 4, 27, 17, 0),
#  datetime.datetime(2014, 4, 27, 18, 0),
#  datetime.datetime(2014, 4, 27, 19, 0),
#  datetime.datetime(2014, 4, 27, 20, 0),
#  datetime.datetime(2014, 4, 27, 21, 0),
#  datetime.datetime(2014, 4, 27, 22, 0),
#  datetime.datetime(2014, 4, 27, 23, 0),
#  datetime.datetime(2014, 4, 28, 0, 0),
#  datetime.datetime(2014, 4, 28, 1, 0),
#  datetime.datetime(2014, 4, 28, 2, 0),
#  datetime.datetime(2014, 4, 28, 3, 0),
#  datetime.datetime(2014, 4, 28, 13, 0),
#  datetime.datetime(2014, 4, 28, 14, 0),
#  datetime.datetime(2014, 4, 28, 15, 0),
#  datetime.datetime(2014, 4, 28, 16, 0),
#  datetime.datetime(2014, 4, 28, 17, 0),
#  datetime.datetime(2014, 4, 28, 18, 0),
#  datetime.datetime(2014, 4, 28, 19, 0),
#  datetime.datetime(2014, 4, 28, 20, 0),
#  datetime.datetime(2014, 4, 28, 21, 0),
#  datetime.datetime(2014, 4, 28, 22, 0),
#  datetime.datetime(2014, 4, 28, 23, 0),
#  datetime.datetime(2014, 4, 29, 0, 0),
#  datetime.datetime(2014, 4, 29, 1, 0),
#  datetime.datetime(2014, 4, 29, 2, 0),
#  datetime.datetime(2014, 4, 29, 3, 0),
#  datetime.datetime(2014, 4, 29, 13, 0),
#  datetime.datetime(2014, 4, 29, 14, 0),
#  datetime.datetime(2014, 4, 29, 15, 0),
#  datetime.datetime(2014, 4, 29, 16, 0),
#  datetime.datetime(2014, 4, 29, 17, 0),
#  datetime.datetime(2014, 4, 29, 18, 0),
#  datetime.datetime(2014, 4, 29, 19, 0),
#  datetime.datetime(2014, 4, 29, 20, 0),
#  datetime.datetime(2014, 4, 29, 21, 0),
#  datetime.datetime(2014, 4, 29, 22, 0),
#  datetime.datetime(2014, 4, 29, 23, 0),
#  datetime.datetime(2014, 4, 30, 0, 0),
#  datetime.datetime(2014, 4, 30, 1, 0),
#  datetime.datetime(2014, 4, 30, 2, 0),
#  datetime.datetime(2014, 4, 30, 3, 0),
#  datetime.datetime(2014, 4, 30, 13, 0),
#  datetime.datetime(2014, 4, 30, 14, 0),
#  datetime.datetime(2014, 4, 30, 15, 0),
#  datetime.datetime(2014, 4, 30, 16, 0),
#  datetime.datetime(2014, 4, 30, 17, 0),
#  datetime.datetime(2014, 4, 30, 18, 0),
#  datetime.datetime(2014, 4, 30, 19, 0),
#  datetime.datetime(2014, 4, 30, 20, 0),
#  datetime.datetime(2014, 4, 30, 21, 0),
#  datetime.datetime(2014, 4, 30, 22, 0),
#  datetime.datetime(2014, 4, 30, 23, 0),
#  datetime.datetime(2014, 5, 1, 0, 0),
#  datetime.datetime(2014, 5, 1, 1, 0),
#  datetime.datetime(2014, 5, 1, 2, 0),
#  datetime.datetime(2014, 5, 1, 3, 0),
#  datetime.datetime(2014, 5, 1, 13, 0),
#  datetime.datetime(2014, 5, 1, 14, 0),
#  datetime.datetime(2014, 5, 1, 15, 0),
#  datetime.datetime(2014, 5, 1, 16, 0),
#  datetime.datetime(2014, 5, 1, 17, 0),
#  datetime.datetime(2014, 5, 1, 18, 0),
#  datetime.datetime(2014, 5, 1, 19, 0),
#  datetime.datetime(2014, 5, 1, 20, 0),
#  datetime.datetime(2014, 5, 1, 21, 0),
#  datetime.datetime(2014, 5, 1, 22, 0),
#  datetime.datetime(2014, 5, 1, 23, 0),
#  datetime.datetime(2014, 5, 2, 0, 0),
#  datetime.datetime(2014, 5, 2, 1, 0),
#  datetime.datetime(2014, 5, 2, 2, 0),
#  datetime.datetime(2014, 5, 2, 3, 0),
#  datetime.datetime(2014, 5, 2, 13, 0),
#  datetime.datetime(2014, 5, 2, 14, 0),
#  datetime.datetime(2014, 5, 2, 15, 0),
#  datetime.datetime(2014, 5, 2, 16, 0),
#  datetime.datetime(2014, 5, 2, 17, 0),
#  datetime.datetime(2014, 5, 2, 18, 0),
#  datetime.datetime(2014, 5, 2, 19, 0),
#  datetime.datetime(2014, 5, 2, 20, 0),
#  datetime.datetime(2014, 5, 2, 21, 0),
#  datetime.datetime(2014, 5, 2, 22, 0),
#  datetime.datetime(2014, 5, 2, 23, 0),
#  datetime.datetime(2014, 5, 3, 0, 0),
#  datetime.datetime(2014, 5, 3, 1, 0),
#  datetime.datetime(2014, 5, 3, 2, 0),
#  datetime.datetime(2014, 5, 3, 3, 0),
#  datetime.datetime(2014, 5, 3, 13, 0),
#  datetime.datetime(2014, 5, 3, 14, 0),
#  datetime.datetime(2014, 5, 3, 15, 0),
#  datetime.datetime(2014, 5, 3, 16, 0),
#  datetime.datetime(2014, 5, 3, 17, 0),
#  datetime.datetime(2014, 5, 3, 18, 0),
#  datetime.datetime(2014, 5, 3, 19, 0),
#  datetime.datetime(2014, 5, 3, 20, 0),
#  datetime.datetime(2014, 5, 3, 21, 0),
#  datetime.datetime(2014, 5, 3, 22, 0),
#  datetime.datetime(2014, 5, 3, 23, 0),
#  datetime.datetime(2014, 5, 4, 0, 0),
#  datetime.datetime(2014, 5, 4, 1, 0),
#  datetime.datetime(2014, 5, 4, 2, 0),
#  datetime.datetime(2014, 5, 4, 3, 0),
#  datetime.datetime(2014, 5, 4, 13, 0),
#  datetime.datetime(2014, 5, 4, 14, 0),
#  datetime.datetime(2014, 5, 4, 15, 0),
#  datetime.datetime(2014, 5, 4, 16, 0),
#  datetime.datetime(2014, 5, 4, 17, 0),
#  datetime.datetime(2014, 5, 4, 18, 0),
#  datetime.datetime(2014, 5, 4, 19, 0),
#  datetime.datetime(2014, 5, 4, 20, 0),
#  datetime.datetime(2014, 5, 4, 21, 0),
#  datetime.datetime(2014, 5, 4, 22, 0),
#  datetime.datetime(2014, 5, 4, 23, 0),
#  datetime.datetime(2014, 5, 5, 0, 0),
#  datetime.datetime(2014, 5, 5, 1, 0),
#  datetime.datetime(2014, 5, 5, 2, 0),
#  datetime.datetime(2014, 5, 5, 3, 0),
#  datetime.datetime(2014, 5, 5, 13, 0),
#  datetime.datetime(2014, 5, 5, 14, 0),
#  datetime.datetime(2014, 5, 5, 15, 0),
#  datetime.datetime(2014, 5, 5, 16, 0),
#  datetime.datetime(2014, 5, 5, 17, 0),
#  datetime.datetime(2014, 5, 5, 18, 0),
#  datetime.datetime(2014, 5, 5, 19, 0),
#  datetime.datetime(2014, 5, 5, 20, 0),
#  datetime.datetime(2014, 5, 5, 21, 0),
#  datetime.datetime(2014, 5, 5, 22, 0),
#  datetime.datetime(2014, 5, 5, 23, 0),
#  datetime.datetime(2014, 5, 6, 0, 0),
#  datetime.datetime(2014, 5, 6, 1, 0),
#  datetime.datetime(2014, 5, 6, 2, 0),
#  datetime.datetime(2014, 5, 6, 3, 0),
#  datetime.datetime(2014, 5, 6, 13, 0),
#  datetime.datetime(2014, 5, 6, 14, 0),
#  datetime.datetime(2014, 5, 6, 15, 0),
#  datetime.datetime(2014, 5, 6, 16, 0),
#  datetime.datetime(2014, 5, 6, 17, 0),
#  datetime.datetime(2014, 5, 6, 18, 0),
#  datetime.datetime(2014, 5, 6, 19, 0),
#  datetime.datetime(2014, 5, 6, 20, 0),
#  datetime.datetime(2014, 5, 6, 21, 0),
#  datetime.datetime(2014, 5, 6, 22, 0),
#  datetime.datetime(2014, 5, 6, 23, 0),
#  datetime.datetime(2014, 5, 7, 0, 0),
#  datetime.datetime(2014, 5, 7, 1, 0),
#  datetime.datetime(2014, 5, 7, 2, 0),
#  datetime.datetime(2014, 5, 7, 3, 0),
#  datetime.datetime(2014, 5, 7, 13, 0),
#  datetime.datetime(2014, 5, 7, 14, 0),
#  datetime.datetime(2014, 5, 7, 15, 0),
#  datetime.datetime(2014, 5, 7, 16, 0),
#  datetime.datetime(2014, 5, 7, 17, 0),
#  datetime.datetime(2014, 5, 7, 18, 0),
#  datetime.datetime(2014, 5, 7, 19, 0),
#  datetime.datetime(2014, 5, 7, 20, 0),
#  datetime.datetime(2014, 5, 7, 21, 0),
#  datetime.datetime(2014, 5, 7, 22, 0),
#  datetime.datetime(2014, 5, 7, 23, 0),
#  datetime.datetime(2014, 5, 8, 0, 0),
#  datetime.datetime(2014, 5, 8, 1, 0),
#  datetime.datetime(2014, 5, 8, 2, 0),
#  datetime.datetime(2014, 5, 8, 3, 0),
#  datetime.datetime(2014, 5, 8, 13, 0),
#  datetime.datetime(2014, 5, 8, 14, 0),
#  datetime.datetime(2014, 5, 8, 15, 0),
#  datetime.datetime(2014, 5, 8, 16, 0),
#  datetime.datetime(2014, 5, 8, 17, 0),
#  datetime.datetime(2014, 5, 8, 18, 0),
#  datetime.datetime(2014, 5, 8, 19, 0),
#  datetime.datetime(2014, 5, 8, 20, 0),
#  datetime.datetime(2014, 5, 8, 21, 0),
#  datetime.datetime(2014, 5, 8, 22, 0),
#  datetime.datetime(2014, 5, 8, 23, 0),
#  datetime.datetime(2014, 5, 9, 0, 0),
#  datetime.datetime(2014, 5, 9, 1, 0),
#  datetime.datetime(2014, 5, 9, 2, 0),
#  datetime.datetime(2014, 5, 9, 3, 0),
#  datetime.datetime(2014, 5, 9, 13, 0),
#  datetime.datetime(2014, 5, 9, 14, 0),
#  datetime.datetime(2014, 5, 9, 15, 0),
#  datetime.datetime(2014, 5, 9, 16, 0),
#  datetime.datetime(2014, 5, 9, 17, 0),
#  datetime.datetime(2014, 5, 9, 18, 0),
#  datetime.datetime(2014, 5, 9, 19, 0),
#  datetime.datetime(2014, 5, 9, 20, 0),
#  datetime.datetime(2014, 5, 9, 21, 0),
#  datetime.datetime(2014, 5, 9, 22, 0),
#  datetime.datetime(2014, 5, 9, 23, 0),
#  datetime.datetime(2014, 5, 10, 0, 0),
#  datetime.datetime(2014, 5, 10, 1, 0),
#  datetime.datetime(2014, 5, 10, 2, 0),
#  datetime.datetime(2014, 5, 10, 3, 0),
#  datetime.datetime(2014, 5, 10, 13, 0),
#  datetime.datetime(2014, 5, 10, 14, 0),
#  datetime.datetime(2014, 5, 10, 15, 0),
#  datetime.datetime(2014, 5, 10, 16, 0),
#  datetime.datetime(2014, 5, 10, 17, 0),
#  datetime.datetime(2014, 5, 10, 18, 0),
#  datetime.datetime(2014, 5, 10, 19, 0),
#  datetime.datetime(2014, 5, 10, 20, 0),
#  datetime.datetime(2014, 5, 10, 21, 0),
#  datetime.datetime(2014, 5, 10, 22, 0),
#  datetime.datetime(2014, 5, 10, 23, 0),
#  datetime.datetime(2014, 5, 11, 0, 0),
#  datetime.datetime(2014, 5, 11, 1, 0),
#  datetime.datetime(2014, 5, 11, 2, 0),
#  datetime.datetime(2014, 5, 11, 3, 0),
#  datetime.datetime(2014, 5, 11, 13, 0),
#  datetime.datetime(2014, 5, 11, 14, 0),
#  datetime.datetime(2014, 5, 11, 15, 0),
#  datetime.datetime(2014, 5, 11, 16, 0),
#  datetime.datetime(2014, 5, 11, 17, 0),
#  datetime.datetime(2014, 5, 11, 18, 0),
#  datetime.datetime(2014, 5, 11, 19, 0),
#  datetime.datetime(2014, 5, 11, 20, 0),
#  datetime.datetime(2014, 5, 11, 21, 0),
#  datetime.datetime(2014, 5, 11, 22, 0),
#  datetime.datetime(2014, 5, 11, 23, 0),
#  datetime.datetime(2014, 5, 12, 0, 0),
#  datetime.datetime(2014, 5, 12, 1, 0),
#  datetime.datetime(2014, 5, 12, 2, 0),
#  datetime.datetime(2014, 5, 12, 3, 0),
#  datetime.datetime(2014, 5, 12, 13, 0),
#  datetime.datetime(2014, 5, 12, 14, 0),
#  datetime.datetime(2014, 5, 12, 15, 0),
#  datetime.datetime(2014, 5, 12, 16, 0),
#  datetime.datetime(2014, 5, 12, 17, 0),
#  datetime.datetime(2014, 5, 12, 18, 0),
#  datetime.datetime(2014, 5, 12, 19, 0),
#  datetime.datetime(2014, 5, 12, 20, 0),
#  datetime.datetime(2014, 5, 12, 21, 0),
#  datetime.datetime(2014, 5, 12, 22, 0),
#  datetime.datetime(2014, 5, 12, 23, 0),
#  datetime.datetime(2014, 5, 13, 0, 0),
#  datetime.datetime(2014, 5, 13, 1, 0),
#  datetime.datetime(2014, 5, 13, 2, 0),
#  datetime.datetime(2014, 5, 13, 3, 0),
#  datetime.datetime(2014, 5, 13, 13, 0),
#  datetime.datetime(2014, 5, 13, 14, 0),
#  datetime.datetime(2014, 5, 13, 15, 0),
#  datetime.datetime(2014, 5, 13, 16, 0),
#  datetime.datetime(2014, 5, 13, 17, 0),
#  datetime.datetime(2014, 5, 13, 18, 0),
#  datetime.datetime(2014, 5, 13, 19, 0),
#  datetime.datetime(2014, 5, 13, 20, 0),
#  datetime.datetime(2014, 5, 13, 21, 0),
#  datetime.datetime(2014, 5, 13, 22, 0),
#  datetime.datetime(2014, 5, 13, 23, 0),
#  datetime.datetime(2014, 5, 14, 0, 0),
#  datetime.datetime(2014, 5, 14, 1, 0),
#  datetime.datetime(2014, 5, 14, 2, 0),
#  datetime.datetime(2014, 5, 14, 3, 0),
#  datetime.datetime(2014, 5, 14, 13, 0),
#  datetime.datetime(2014, 5, 14, 14, 0),
#  datetime.datetime(2014, 5, 14, 15, 0),
#  datetime.datetime(2014, 5, 14, 16, 0),
#  datetime.datetime(2014, 5, 14, 17, 0),
#  datetime.datetime(2014, 5, 14, 18, 0),
#  datetime.datetime(2014, 5, 14, 19, 0),
#  datetime.datetime(2014, 5, 14, 20, 0),
#  datetime.datetime(2014, 5, 14, 21, 0),
#  datetime.datetime(2014, 5, 14, 22, 0),
#  datetime.datetime(2014, 5, 14, 23, 0),
#  datetime.datetime(2014, 5, 15, 0, 0),
#  datetime.datetime(2014, 5, 15, 1, 0),
#  datetime.datetime(2014, 5, 15, 2, 0),
#  datetime.datetime(2014, 5, 15, 3, 0),
#  datetime.datetime(2014, 5, 15, 13, 0),
#  datetime.datetime(2014, 5, 15, 14, 0),
#  datetime.datetime(2014, 5, 15, 15, 0),
#  datetime.datetime(2014, 5, 15, 16, 0),
#  datetime.datetime(2014, 5, 15, 17, 0),
#  datetime.datetime(2014, 5, 15, 18, 0),
#  datetime.datetime(2014, 5, 15, 19, 0),
#  datetime.datetime(2014, 5, 15, 20, 0),
#  datetime.datetime(2014, 5, 15, 21, 0),
#  datetime.datetime(2014, 5, 15, 22, 0),
#  datetime.datetime(2014, 5, 15, 23, 0),
#  datetime.datetime(2014, 5, 16, 0, 0),
#  datetime.datetime(2014, 5, 16, 1, 0),
#  datetime.datetime(2014, 5, 16, 2, 0),
#  datetime.datetime(2014, 5, 16, 3, 0),
#  datetime.datetime(2014, 5, 16, 13, 0),
#  datetime.datetime(2014, 5, 16, 14, 0),
#  datetime.datetime(2014, 5, 16, 15, 0),
#  datetime.datetime(2014, 5, 16, 16, 0),
#  datetime.datetime(2014, 5, 16, 17, 0),
#  datetime.datetime(2014, 5, 16, 18, 0),
#  datetime.datetime(2014, 5, 16, 19, 0),
#  datetime.datetime(2014, 5, 16, 20, 0),
#  datetime.datetime(2014, 5, 16, 21, 0),
#  datetime.datetime(2014, 5, 16, 22, 0),
#  datetime.datetime(2014, 5, 16, 23, 0),
#  datetime.datetime(2014, 5, 17, 0, 0),
#  datetime.datetime(2014, 5, 17, 1, 0),
#  datetime.datetime(2014, 5, 17, 2, 0),
#  datetime.datetime(2014, 5, 17, 3, 0),
#  datetime.datetime(2014, 5, 17, 13, 0),
#  datetime.datetime(2014, 5, 17, 14, 0),
#  datetime.datetime(2014, 5, 17, 15, 0),
#  datetime.datetime(2014, 5, 17, 16, 0),
#  datetime.datetime(2014, 5, 17, 17, 0),
#  datetime.datetime(2014, 5, 17, 18, 0),
#  datetime.datetime(2014, 5, 17, 19, 0),
#  datetime.datetime(2014, 5, 17, 20, 0),
#  datetime.datetime(2014, 5, 17, 21, 0),
#  datetime.datetime(2014, 5, 17, 22, 0),
#  datetime.datetime(2014, 5, 17, 23, 0),
#  datetime.datetime(2014, 5, 18, 0, 0),
#  datetime.datetime(2014, 5, 18, 1, 0),
#  datetime.datetime(2014, 5, 18, 2, 0),
#  datetime.datetime(2014, 5, 18, 3, 0),
#  datetime.datetime(2014, 5, 18, 13, 0),
#  datetime.datetime(2014, 5, 18, 14, 0),
#  datetime.datetime(2014, 5, 18, 15, 0),
#  datetime.datetime(2014, 5, 18, 16, 0),
#  datetime.datetime(2014, 5, 18, 17, 0),
#  datetime.datetime(2014, 5, 18, 18, 0),
#  datetime.datetime(2014, 5, 18, 19, 0),
#  datetime.datetime(2014, 5, 18, 20, 0),
#  datetime.datetime(2014, 5, 18, 21, 0),
#  datetime.datetime(2014, 5, 18, 22, 0),
#  datetime.datetime(2014, 5, 18, 23, 0),
#  datetime.datetime(2014, 5, 19, 0, 0),
#  datetime.datetime(2014, 5, 19, 1, 0),
#  datetime.datetime(2014, 5, 19, 2, 0),
#  datetime.datetime(2014, 5, 19, 3, 0),
#  datetime.datetime(2014, 5, 19, 13, 0),
#  datetime.datetime(2014, 5, 19, 14, 0),
#  datetime.datetime(2014, 5, 19, 15, 0),
#  datetime.datetime(2014, 5, 19, 16, 0),
#  datetime.datetime(2014, 5, 19, 17, 0),
#  datetime.datetime(2014, 5, 19, 18, 0),
#  datetime.datetime(2014, 5, 19, 19, 0),
#  datetime.datetime(2014, 5, 19, 20, 0),
#  datetime.datetime(2014, 5, 19, 21, 0),
#  datetime.datetime(2014, 5, 19, 22, 0),
#  datetime.datetime(2014, 5, 19, 23, 0),
#  datetime.datetime(2014, 5, 20, 0, 0),
#  datetime.datetime(2014, 5, 20, 1, 0),
#  datetime.datetime(2014, 5, 20, 2, 0),
#  datetime.datetime(2014, 5, 20, 3, 0),
#  datetime.datetime(2014, 5, 20, 13, 0),
#  datetime.datetime(2014, 5, 20, 14, 0),
#  datetime.datetime(2014, 5, 20, 15, 0),
#  datetime.datetime(2014, 5, 20, 16, 0),
#  datetime.datetime(2014, 5, 20, 17, 0),
#  datetime.datetime(2014, 5, 20, 18, 0),
#  datetime.datetime(2014, 5, 20, 19, 0),
#  datetime.datetime(2014, 5, 20, 20, 0),
#  datetime.datetime(2014, 5, 20, 21, 0),
#  datetime.datetime(2014, 5, 20, 22, 0),
#  datetime.datetime(2014, 5, 20, 23, 0),
#  datetime.datetime(2014, 5, 21, 0, 0),
#  datetime.datetime(2014, 5, 21, 1, 0),
#  datetime.datetime(2014, 5, 21, 2, 0),
#  datetime.datetime(2014, 5, 21, 3, 0),
#  datetime.datetime(2014, 5, 21, 13, 0),
#  datetime.datetime(2014, 5, 21, 14, 0),
#  datetime.datetime(2014, 5, 21, 15, 0),
#  datetime.datetime(2014, 5, 21, 16, 0),
#  datetime.datetime(2014, 5, 21, 17, 0),
#  datetime.datetime(2014, 5, 21, 18, 0),
#  datetime.datetime(2014, 5, 21, 19, 0),
#  datetime.datetime(2014, 5, 21, 20, 0),
#  datetime.datetime(2014, 5, 21, 21, 0),
#  datetime.datetime(2014, 5, 21, 22, 0),
#  datetime.datetime(2014, 5, 21, 23, 0),
#  datetime.datetime(2014, 5, 22, 0, 0),
#  datetime.datetime(2014, 5, 22, 1, 0),
#  datetime.datetime(2014, 5, 22, 2, 0),
#  datetime.datetime(2014, 5, 22, 3, 0),
#  datetime.datetime(2014, 5, 22, 13, 0),
#  datetime.datetime(2014, 5, 22, 14, 0),
#  datetime.datetime(2014, 5, 22, 15, 0),
#  datetime.datetime(2014, 5, 22, 16, 0),
#  datetime.datetime(2014, 5, 22, 17, 0),
#  datetime.datetime(2014, 5, 22, 18, 0),
#  datetime.datetime(2014, 5, 22, 19, 0),
#  datetime.datetime(2014, 5, 22, 20, 0),
#  datetime.datetime(2014, 5, 22, 21, 0),
#  datetime.datetime(2014, 5, 22, 22, 0),
#  datetime.datetime(2014, 5, 22, 23, 0),
#  datetime.datetime(2014, 5, 23, 0, 0),
#  datetime.datetime(2014, 5, 23, 1, 0),
#  datetime.datetime(2014, 5, 23, 2, 0),
#  datetime.datetime(2014, 5, 23, 3, 0),
#  datetime.datetime(2014, 5, 23, 13, 0),
#  datetime.datetime(2014, 5, 23, 14, 0),
#  datetime.datetime(2014, 5, 23, 15, 0),
#  datetime.datetime(2014, 5, 23, 16, 0),
#  datetime.datetime(2014, 5, 23, 17, 0),
#  datetime.datetime(2014, 5, 23, 18, 0),
#  datetime.datetime(2014, 5, 23, 19, 0),
#  datetime.datetime(2014, 5, 23, 20, 0),
#  datetime.datetime(2014, 5, 23, 21, 0),
#  datetime.datetime(2014, 5, 23, 22, 0),
#  datetime.datetime(2014, 5, 23, 23, 0),
#  datetime.datetime(2014, 5, 24, 0, 0),
#  datetime.datetime(2014, 5, 24, 1, 0),
#  datetime.datetime(2014, 5, 24, 2, 0),
#  datetime.datetime(2014, 5, 24, 3, 0),
#  datetime.datetime(2014, 5, 24, 13, 0),
#  datetime.datetime(2014, 5, 24, 14, 0),
#  datetime.datetime(2014, 5, 24, 15, 0),
#  datetime.datetime(2014, 5, 24, 16, 0),
#  datetime.datetime(2014, 5, 24, 17, 0),
#  datetime.datetime(2014, 5, 24, 18, 0),
#  datetime.datetime(2014, 5, 24, 19, 0),
#  datetime.datetime(2014, 5, 24, 20, 0),
#  datetime.datetime(2014, 5, 24, 21, 0),
#  datetime.datetime(2014, 5, 24, 22, 0),
#  datetime.datetime(2014, 5, 24, 23, 0),
#  datetime.datetime(2014, 5, 25, 0, 0),
#  datetime.datetime(2014, 5, 25, 1, 0),
#  datetime.datetime(2014, 5, 25, 2, 0),
#  datetime.datetime(2014, 5, 25, 3, 0),
#  datetime.datetime(2014, 5, 25, 13, 0),
#  datetime.datetime(2014, 5, 25, 14, 0),
#  datetime.datetime(2014, 5, 25, 15, 0),
#  datetime.datetime(2014, 5, 25, 16, 0),
#  datetime.datetime(2014, 5, 25, 17, 0),
#  datetime.datetime(2014, 5, 25, 18, 0),
#  datetime.datetime(2014, 5, 25, 19, 0),
#  datetime.datetime(2014, 5, 25, 20, 0),
#  datetime.datetime(2014, 5, 25, 21, 0),
#  datetime.datetime(2014, 5, 25, 22, 0),
#  datetime.datetime(2014, 5, 25, 23, 0),
#  datetime.datetime(2014, 5, 26, 0, 0),
#  datetime.datetime(2014, 5, 26, 1, 0),
#  datetime.datetime(2014, 5, 26, 2, 0),
#  datetime.datetime(2014, 5, 26, 3, 0),
#  datetime.datetime(2014, 5, 26, 13, 0),
#  datetime.datetime(2014, 5, 26, 14, 0),
#  datetime.datetime(2014, 5, 26, 15, 0),
#  datetime.datetime(2014, 5, 26, 16, 0),
#  datetime.datetime(2014, 5, 26, 17, 0),
#  datetime.datetime(2014, 5, 26, 18, 0),
#  datetime.datetime(2014, 5, 26, 19, 0),
#  datetime.datetime(2014, 5, 26, 20, 0),
#  datetime.datetime(2014, 5, 26, 21, 0),
#  datetime.datetime(2014, 5, 26, 22, 0),
#  datetime.datetime(2014, 5, 26, 23, 0),
#  datetime.datetime(2014, 5, 27, 0, 0),
#  datetime.datetime(2014, 5, 27, 1, 0),
#  datetime.datetime(2014, 5, 27, 2, 0),
#  datetime.datetime(2014, 5, 27, 3, 0),
#  datetime.datetime(2014, 5, 27, 13, 0),
#  datetime.datetime(2014, 5, 27, 14, 0),
#  datetime.datetime(2014, 5, 27, 15, 0),
#  datetime.datetime(2014, 5, 27, 16, 0),
#  datetime.datetime(2014, 5, 27, 17, 0),
#  datetime.datetime(2014, 5, 27, 18, 0),
#  datetime.datetime(2014, 5, 27, 19, 0),
#  datetime.datetime(2014, 5, 27, 20, 0),
#  datetime.datetime(2014, 5, 27, 21, 0),
#  datetime.datetime(2014, 5, 27, 22, 0),
#  datetime.datetime(2014, 5, 27, 23, 0),
#  datetime.datetime(2014, 5, 28, 0, 0),
#  datetime.datetime(2014, 5, 28, 1, 0),
#  datetime.datetime(2014, 5, 28, 2, 0),
#  datetime.datetime(2014, 5, 28, 3, 0),
#  datetime.datetime(2014, 5, 28, 13, 0),
#  datetime.datetime(2014, 5, 28, 14, 0),
#  datetime.datetime(2014, 5, 28, 15, 0),
#  datetime.datetime(2014, 5, 28, 16, 0),
#  datetime.datetime(2014, 5, 28, 17, 0),
#  datetime.datetime(2014, 5, 28, 18, 0),
#  datetime.datetime(2014, 5, 28, 19, 0),
#  datetime.datetime(2014, 5, 28, 20, 0),
#  datetime.datetime(2014, 5, 28, 21, 0),
#  datetime.datetime(2014, 5, 28, 22, 0),
#  datetime.datetime(2014, 5, 28, 23, 0),
#  datetime.datetime(2014, 5, 29, 0, 0),
#  datetime.datetime(2014, 5, 29, 1, 0),
#  datetime.datetime(2014, 5, 29, 2, 0),
#  datetime.datetime(2014, 5, 29, 3, 0),
#  datetime.datetime(2014, 5, 29, 13, 0),
#  datetime.datetime(2014, 5, 29, 14, 0),
#  datetime.datetime(2014, 5, 29, 15, 0),
#  datetime.datetime(2014, 5, 29, 16, 0),
#  datetime.datetime(2014, 5, 29, 17, 0),
#  datetime.datetime(2014, 5, 29, 18, 0),
#  datetime.datetime(2014, 5, 29, 19, 0),
#  datetime.datetime(2014, 5, 29, 20, 0),
#  datetime.datetime(2014, 5, 29, 21, 0),
#  datetime.datetime(2014, 5, 29, 22, 0),
#  datetime.datetime(2014, 5, 29, 23, 0),
#  datetime.datetime(2014, 5, 30, 0, 0),
#  datetime.datetime(2014, 5, 30, 1, 0),
#  datetime.datetime(2014, 5, 30, 2, 0),
#  datetime.datetime(2014, 5, 30, 3, 0),
#  datetime.datetime(2014, 5, 30, 13, 0),
#  datetime.datetime(2014, 5, 30, 14, 0),
#  datetime.datetime(2014, 5, 30, 15, 0),
#  datetime.datetime(2014, 5, 30, 16, 0),
#  datetime.datetime(2014, 5, 30, 17, 0),
#  datetime.datetime(2014, 5, 30, 18, 0),
#  datetime.datetime(2014, 5, 30, 19, 0),
#  datetime.datetime(2014, 5, 30, 20, 0),
#  datetime.datetime(2014, 5, 30, 21, 0),
#  datetime.datetime(2014, 5, 30, 22, 0),
#  datetime.datetime(2014, 5, 30, 23, 0),
#  datetime.datetime(2014, 5, 31, 0, 0),
#  datetime.datetime(2014, 5, 31, 1, 0),
#  datetime.datetime(2014, 5, 31, 2, 0),
#  datetime.datetime(2014, 5, 31, 3, 0),
#  datetime.datetime(2014, 5, 31, 13, 0),
#  datetime.datetime(2014, 5, 31, 14, 0),
#  datetime.datetime(2014, 5, 31, 15, 0),
#  datetime.datetime(2014, 5, 31, 16, 0),
#  datetime.datetime(2014, 5, 31, 17, 0),
#  datetime.datetime(2014, 5, 31, 18, 0),
#  datetime.datetime(2014, 5, 31, 19, 0),
#  datetime.datetime(2014, 5, 31, 20, 0),
#  datetime.datetime(2014, 5, 31, 21, 0),
#  datetime.datetime(2014, 5, 31, 22, 0),
#  datetime.datetime(2014, 5, 31, 23, 0),
#  datetime.datetime(2014, 6, 1, 0, 0),
#  datetime.datetime(2014, 6, 1, 1, 0),
#  datetime.datetime(2014, 6, 1, 2, 0),
#  datetime.datetime(2014, 6, 1, 3, 0),
#  datetime.datetime(2014, 6, 1, 13, 0),
#  datetime.datetime(2014, 6, 1, 14, 0),
#  datetime.datetime(2014, 6, 1, 15, 0),
#  datetime.datetime(2014, 6, 1, 16, 0),
#  datetime.datetime(2014, 6, 1, 17, 0),
#  datetime.datetime(2014, 6, 1, 18, 0),
#  datetime.datetime(2014, 6, 1, 19, 0),
#  datetime.datetime(2014, 6, 1, 20, 0),
#  datetime.datetime(2014, 6, 1, 21, 0),
#  datetime.datetime(2014, 6, 1, 22, 0),
#  datetime.datetime(2014, 6, 1, 23, 0),
#  datetime.datetime(2014, 6, 2, 0, 0),
#  datetime.datetime(2014, 6, 2, 1, 0),
#  datetime.datetime(2014, 6, 2, 2, 0),
#  datetime.datetime(2014, 6, 2, 3, 0),
#  datetime.datetime(2014, 6, 2, 13, 0),
#  datetime.datetime(2014, 6, 2, 14, 0),
#  datetime.datetime(2014, 6, 2, 15, 0),
#  datetime.datetime(2014, 6, 2, 16, 0),
#  datetime.datetime(2014, 6, 2, 17, 0),
#  datetime.datetime(2014, 6, 2, 18, 0),
#  datetime.datetime(2014, 6, 2, 19, 0),
#  datetime.datetime(2014, 6, 2, 20, 0),
#  datetime.datetime(2014, 6, 2, 21, 0),
#  datetime.datetime(2014, 6, 2, 22, 0),
#  datetime.datetime(2014, 6, 2, 23, 0),
#  datetime.datetime(2014, 6, 3, 0, 0),
#  datetime.datetime(2014, 6, 3, 1, 0),
#  datetime.datetime(2014, 6, 3, 2, 0),
#  datetime.datetime(2014, 6, 3, 3, 0),
#  datetime.datetime(2014, 6, 3, 13, 0),
#  datetime.datetime(2014, 6, 3, 14, 0),
#  datetime.datetime(2014, 6, 3, 15, 0),
#  datetime.datetime(2014, 6, 3, 16, 0),
#  datetime.datetime(2014, 6, 3, 17, 0),
#  datetime.datetime(2014, 6, 3, 18, 0),
#  datetime.datetime(2014, 6, 3, 19, 0),
#  datetime.datetime(2014, 6, 3, 20, 0),
#  datetime.datetime(2014, 6, 3, 21, 0),
#  datetime.datetime(2014, 6, 3, 22, 0),
#  datetime.datetime(2014, 6, 3, 23, 0),
#  datetime.datetime(2014, 6, 4, 0, 0),
#  datetime.datetime(2014, 6, 4, 1, 0),
#  datetime.datetime(2014, 6, 4, 2, 0),
#  datetime.datetime(2014, 6, 4, 3, 0),
#  datetime.datetime(2014, 6, 4, 13, 0),
#  datetime.datetime(2014, 6, 4, 14, 0),
#  datetime.datetime(2014, 6, 4, 15, 0),
#  datetime.datetime(2014, 6, 4, 16, 0),
#  datetime.datetime(2014, 6, 4, 17, 0),
#  datetime.datetime(2014, 6, 4, 18, 0),
#  datetime.datetime(2014, 6, 4, 19, 0),
#  datetime.datetime(2014, 6, 4, 20, 0),
#  datetime.datetime(2014, 6, 4, 21, 0),
#  datetime.datetime(2014, 6, 4, 22, 0),
#  datetime.datetime(2014, 6, 4, 23, 0),
#  datetime.datetime(2014, 6, 5, 0, 0),
#  datetime.datetime(2014, 6, 5, 1, 0),
#  datetime.datetime(2014, 6, 5, 2, 0),
#  datetime.datetime(2014, 6, 5, 3, 0),
#  datetime.datetime(2014, 6, 5, 13, 0),
#  datetime.datetime(2014, 6, 5, 14, 0),
#  datetime.datetime(2014, 6, 5, 15, 0),
#  datetime.datetime(2014, 6, 5, 16, 0),
#  datetime.datetime(2014, 6, 5, 17, 0),
#  datetime.datetime(2014, 6, 5, 18, 0),
#  datetime.datetime(2014, 6, 5, 19, 0),
#  datetime.datetime(2014, 6, 5, 20, 0),
#  datetime.datetime(2014, 6, 5, 21, 0),
#  datetime.datetime(2014, 6, 5, 22, 0),
#  datetime.datetime(2014, 6, 5, 23, 0),
#  datetime.datetime(2014, 6, 6, 0, 0),
#  datetime.datetime(2014, 6, 6, 1, 0),
#  datetime.datetime(2014, 6, 6, 2, 0),
#  datetime.datetime(2014, 6, 6, 3, 0),
#  datetime.datetime(2014, 6, 6, 13, 0),
#  datetime.datetime(2014, 6, 6, 14, 0),
#  datetime.datetime(2014, 6, 6, 15, 0),
#  datetime.datetime(2014, 6, 6, 16, 0),
#  datetime.datetime(2014, 6, 6, 17, 0),
#  datetime.datetime(2014, 6, 6, 18, 0),
#  datetime.datetime(2014, 6, 6, 19, 0),
#  datetime.datetime(2014, 6, 6, 20, 0),
#  datetime.datetime(2014, 6, 6, 21, 0),
#  datetime.datetime(2014, 6, 6, 22, 0),
#  ...]

# %%
# Now that we can call data up over any datetime and we have a list of interested datetimes,
# we can finally construct an X matrix and y vector for regression.
